# %% [markdown]
# ## Series in pandas:
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
import pandas as pd

list=[2,3,4,5,6,7,8]
new=pd.Series(list, index=[100,101,102,103,104,105,106,],dtype=float)
print(new)
dic={"name":["tahseen","noman","yasir","farhan"],
     "roll-no":[17,18,21,15],
      "subject":["maths","DBMS","DAA","python"]
      }
new1=pd.Series(dic)
print(new1)
print(new1["name"])
# Out:
# 100    2.0
# 101    3.0
# 102    4.0
# 103    5.0
# 104    6.0
# 105    7.0
# 106    8.0
# dtype: float64
# name       [tahseen, noman, yasir, farhan]
# roll-no                   [17, 18, 21, 15]
# subject         [maths, DBMS, DAA, python]
# dtype: object
# ['tahseen', 'noman', 'yasir', 'farhan']

# %% [markdown]
# ### DataFrame in pandas:
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
dic={
    "name":["tahseen","noman","yasir","haroon"],
    "roll-no":[18,17,21,19],
    "subjects":["DBMS","python","maths","DAA"],
}
df=pd.DataFrame(dic,index=[1,2,3,4])
print(df)
print(df.loc[3])
print(df.loc[[1,2]])
# Out:
#       name  roll-no subjects
# 1  tahseen       18     DBMS
# 2    noman       17   python
# 3    yasir       21    maths
# 4   haroon       19      DAA
# name        yasir
# roll-no        21
# subjects    maths
# Name: 3, dtype: object
#       name  roll-no subjects
# 1  tahseen       18     DBMS
# 2    noman       17   python
